# %%
# Creating a dataframe(df1) by reading "IMDB_Rating" CSV file

# %%
import pandas as pd
df1 = pd.read_csv("IMDB_Rating.csv")
df1.head()
# Out:
#      imdb_id  vote_average  vote_count
# 0  tt0114709           7.7        5415
# 1  tt0113497           6.9        2413
# 2  tt0113228           6.5          92
# 3  tt0114885           6.1          34
# 4  tt0113041           5.7         173

# %%
# Creating a dataframe by reading a raw IMDB "movies_metadata" csv file

# %%
df2 = pd.read_csv("movies_metadata.csv", low_memory=False)
df2.head()
# Out:
#      imdb_id  adult                              belongs_to_collection  \
# 0  tt0114709  False  {'id': 10194, 'name': 'Toy Story Collection', ...
# 1  tt0113497  False                                                NaN
# 2  tt0113228  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3  tt0114885  False                                                NaN
# 4  tt0113041  False  {'id': 96871, 'name': 'Father of the Bride Col...
#
#      budget                                             genres  \
# 0  30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2         0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4         0                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id original_language  \
# 0  http://toystory.disney.com/toy-story    862                en
# ...

# %%
# Preprocess the movie metadata file to remove JSON columns

# %%
df2 = df2.drop(['belongs_to_collection', 'genres', 'production_companies', 'production_countries','spoken_languages'], axis = 1)
df2.head()
# Out:
#      imdb_id  adult    budget                              homepage     id  \
# 0  tt0114709  False  30000000  http://toystory.disney.com/toy-story    862
# 1  tt0113497  False  65000000                                   NaN   8844
# 2  tt0113228  False         0                                   NaN  15602
# 3  tt0114885  False  16000000                                   NaN  31357
# 4  tt0113041  False         0                                   NaN  11862
#
#   original_language               original_title  \
# 0                en                    Toy Story
# 1                en                      Jumanji
# 2                en             Grumpier Old Men
# 3                en            Waiting to Exhale
# 4                en  Father of the Bride Part II
#
#                                             overview  popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...   21.946943
# 1  When siblings Judy and Peter discover an encha...   17.015539
# ...

# %%
#Creating a dataframe(df3) by merging the df1 with df2 to create a single file with MovieID as index
#Creating a new dataframe(df4) that contains only the average "user rating" with the "revenue" per rating

# %%
df3 = pd.merge(df1,df2,on='imdb_id')
df3.head()
frames = [df3['vote_average'], df3['revenue']]
df4 = pd.concat(frames, axis=1)
df4 = df4.drop_duplicates(subset=['vote_average'],keep='first')
df4 = df4.sort_values('vote_average')
df4.head()

# %%
#Writing all the dataframes to CSV file

# %%
df2.to_csv("processed_movies_metadat.csv")
df3.to_csv("merged_data_set.csv")
df4.to_csv("revenue_rating.csv")

# %%
#Plotting the comparison revenue with each user rating

# %%
import matplotlib.pyplot as plt
import numpy as np

df4.plot(x='vote_average', y='revenue', figsize=(15,5), kind='bar', width=1)
